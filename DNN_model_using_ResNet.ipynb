# %%
#IMPORTS
import tensorflow as tf
import numpy as np
import pandas as pd
import pathlib
import datetime
import scipy
import matplotlib.pyplot as plt
import math
import os
import tensorboard as tb
import keras_tuner as kt
import skimage.io as io
import skimage.transform as trans
from sklearn.metrics import classification_report
print(os.getcwd())

#Google Drive Setup
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
FOLDERNAME = "cs231n/assignments/assignment5"
assert FOLDERNAME is not None, "[1] Enter the foldername."
import sys
sys.path.append("/content/drive/My Drive/{}".format(FOLDERNAME)) #you have no idea how long I spent figuring out this had to be brackets and not parentheses
#print(sys.path)
# Out:
# /content
# Mounted at /content/drive

# %%
#LOAD DATA
# Shape of inputs to DNN Model
BATCH_SIZE = 32             # Can be of size 2^n, but not restricted to. for the better utilization of memory
IMG_HEIGHT = 224            # input Shape required by the model
IMG_WIDTH = 224             # input Shape required by the model
STEPS_PER_EPOCH = 100 #np.ceil(image_count/BATCH_SIZE)

#DATA PREPROCESSING
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet_v2.preprocess_input)
train_data_gen = image_generator.flow_from_directory(directory=str("/content/drive/My Drive/cs231n/assignments/assignment6/dataset/train"),
                                                        batch_size=BATCH_SIZE,
                                                        shuffle=True,
                                                        target_size=(IMG_HEIGHT, IMG_WIDTH))

val_data_gen = image_generator.flow_from_directory(directory=str("/content/drive/My Drive/cs231n/assignments/assignment6/dataset/val"),
                                                        batch_size=BATCH_SIZE,
                                                        shuffle=True,
                                                        target_size=(IMG_HEIGHT, IMG_WIDTH))
# Out:
# Found 8323 images belonging to 10 classes.
# Found 2084 images belonging to 10 classes.

# %%
#HYPERPARAMETER TUNING (ONLY LR - REGULARIZATION AND NUM_HIDDEN NOT AVAILABLE FOR MODEL, EPOCHS AND LR FURTHER OPTIMIZED USING CALLBACKS)
def model_builder(hp):
  model = tf.keras.applications.ResNet50V2(
    include_top=True,
    weights=None, #"imagenet"
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=10,
    classifier_activation="softmax",
  )

  # LR Tuning
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics=['accuracy', 'mean_squared_error'])

  return model

tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

tuner.search(train_data_gen, epochs=50, validation_data=val_data_gen, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best LR from Hyperparameter Tuning = {}".format(best_hps.get('learning_rate')))
# Out:
# Trial 3 Complete [00h 03m 50s]
# val_accuracy: 0.27639156579971313
#
# Best val_accuracy So Far: 0.41938579082489014
# Total elapsed time: 01h 02m 17s
# INFO:tensorflow:Oracle triggered exit
# Best LR from Hyperparameter Tuning = 0.01

# %%
#LOAD MODEL
#load model
model = tf.keras.applications.ResNet50V2(
    include_top=True,
    weights=None, #"imagenet"
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=10,
    classifier_activation="softmax",
)
#print(model.summary())

#callbacks
#%load_ext tensorboard_callback 
#%tensorboard --logdir logs
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=best_hps.get('learning_rate')), loss="categorical_crossentropy", metrics=['accuracy', 'mean_squared_error'])
#log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
earlystop_cb = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
learningrates_cb = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss')
checkpoint_filepath = '/content/drive/My Drive/cs231n/assignments/assignment6/checkpoints'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
#TRAIN MODEL
#train
history = model.fit(
                train_data_gen,
                steps_per_epoch=STEPS_PER_EPOCH,
                epochs=300, #
                validation_data=val_data_gen,
                validation_batch_size=1,
                validation_steps=32,
                callbacks=[earlystop_cb, learningrates_cb, model_checkpoint_callback]) #tensorboard_callback,
# Out:
# Epoch 1/300
# 100/100 [==============================] - 50s 455ms/step - loss: 2.0941 - accuracy: 0.2308 - mean_squared_error: 0.0855 - val_loss: 2.2674 - val_accuracy: 0.1504 - val_mean_squared_error: 0.0896 - lr: 0.0100
# Epoch 2/300
# 100/100 [==============================] - 45s 450ms/step - loss: 1.9724 - accuracy: 0.2969 - mean_squared_error: 0.0818 - val_loss: 2.1753 - val_accuracy: 0.1826 - val_mean_squared_error: 0.0877 - lr: 0.0100
# Epoch 3/300
# 100/100 [==============================] - 45s 452ms/step - loss: 1.9022 - accuracy: 0.3316 - mean_squared_error: 0.0793 - val_loss: 2.1518 - val_accuracy: 0.2441 - val_mean_squared_error: 0.0856 - lr: 0.0100
# Epoch 4/300
# 100/100 [==============================] - 45s 447ms/step - loss: 1.7787 - accuracy: 0.3756 - mean_squared_error: 0.0754 - val_loss: 1.7106 - val_accuracy: 0.4023 - val_mean_squared_error: 0.0732 - lr: 0.0100
# Epoch 5/300
# 100/100 [==============================] - 44s 438ms/step - loss: 1.6218 - accuracy: 0.4334 - mean_squared_error: 0.0693 - val_loss: 1.7965 - val_accuracy: 0.3438 - val_mean_squared_error: 0.0763 - lr: 0.0100
# Epoch 6/300
# 100/100 [==============================] - 44s 442ms/step - loss: 1.5699 - accuracy: 0.4575 - mean_squared_error: 0.0680 - val_loss: 1.6482 - val_accuracy: 0.3994 - val_mean_squared_error: 0.0717 - lr: 0.0100
# Epoch 7/300
# 100/100 [==============================] - 44s 439ms/step - loss: 1.4892 - accuracy: 0.4891 - mean_squared_error: 0.0652 - val_loss: 1.6872 - val_accuracy: 0.3994 - val_mean_squared_error: 0.0732 - lr: 0.0100
# Epoch 8/300
# 100/100 [==============================] - 44s 442ms/step - loss: 1.3823 - accuracy: 0.5206 - mean_squared_error: 0.0611 - val_loss: 1.5831 - val_accuracy: 0.4492 - val_mean_squared_error: 0.0693 - lr: 0.0100
# Epoch 9/300
# 100/100 [==============================] - 45s 448ms/step - loss: 1.3186 - accuracy: 0.5591 - mean_squared_error: 0.0587 - val_loss: 1.4266 - val_accuracy: 0.5098 - val_mean_squared_error: 0.0622 - lr: 0.0100
# Epoch 10/300
# 100/100 [==============================] - 45s 449ms/step - loss: 1.2346 - accuracy: 0.5866 - mean_squared_error: 0.0549 - val_loss: 1.2468 - val_accuracy: 0.5762 - val_mean_squared_error: 0.0552 - lr: 0.0100
# Epoch 11/300
# 100/100 [==============================] - 45s 444ms/step - loss: 1.1213 - accuracy: 0.6331 - mean_squared_error: 0.0507 - val_loss: 1.2211 - val_accuracy: 0.5713 - val_mean_squared_error: 0.0544 - lr: 0.0100
# Epoch 12/300
# 100/100 [==============================] - 44s 439ms/step - loss: 1.0322 - accuracy: 0.6619 - mean_squared_error: 0.0465 - val_loss: 1.5957 - val_accuracy: 0.5352 - val_mean_squared_error: 0.0654 - lr: 0.0100
# Epoch 13/300
# 100/100 [==============================] - 44s 442ms/step - loss: 0.9588 - accuracy: 0.6897 - mean_squared_error: 0.0436 - val_loss: 1.2439 - val_accuracy: 0.6025 - val_mean_squared_error: 0.0545 - lr: 0.0100
# Epoch 14/300
# 100/100 [==============================] - 45s 448ms/step - loss: 0.9088 - accuracy: 0.7050 - mean_squared_error: 0.0415 - val_loss: 1.1588 - val_accuracy: 0.6357 - val_mean_squared_error: 0.0511 - lr: 0.0100
# Epoch 15/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.8605 - accuracy: 0.7307 - mean_squared_error: 0.0392 - val_loss: 1.0464 - val_accuracy: 0.6572 - val_mean_squared_error: 0.0468 - lr: 0.0100
# Epoch 16/300
# 100/100 [==============================] - 44s 437ms/step - loss: 0.7858 - accuracy: 0.7544 - mean_squared_error: 0.0361 - val_loss: 1.3358 - val_accuracy: 0.6016 - val_mean_squared_error: 0.0574 - lr: 0.0100
# Epoch 17/300
# 100/100 [==============================] - 44s 435ms/step - loss: 0.7119 - accuracy: 0.7852 - mean_squared_error: 0.0323 - val_loss: 1.1490 - val_accuracy: 0.6387 - val_mean_squared_error: 0.0503 - lr: 0.0100
# Epoch 18/300
# 100/100 [==============================] - 44s 441ms/step - loss: 0.6189 - accuracy: 0.8103 - mean_squared_error: 0.0283 - val_loss: 0.9223 - val_accuracy: 0.7148 - val_mean_squared_error: 0.0417 - lr: 0.0100
# Epoch 19/300
# 100/100 [==============================] - 44s 436ms/step - loss: 0.6313 - accuracy: 0.8026 - mean_squared_error: 0.0291 - val_loss: 0.9726 - val_accuracy: 0.6982 - val_mean_squared_error: 0.0428 - lr: 0.0100
# Epoch 20/300
# 100/100 [==============================] - 44s 440ms/step - loss: 0.5117 - accuracy: 0.8372 - mean_squared_error: 0.0239 - val_loss: 0.9779 - val_accuracy: 0.6953 - val_mean_squared_error: 0.0425 - lr: 0.0100
# Epoch 21/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.4600 - accuracy: 0.8609 - mean_squared_error: 0.0212 - val_loss: 0.8858 - val_accuracy: 0.7295 - val_mean_squared_error: 0.0381 - lr: 0.0100
# Epoch 22/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.4133 - accuracy: 0.8710 - mean_squared_error: 0.0192 - val_loss: 0.7098 - val_accuracy: 0.7832 - val_mean_squared_error: 0.0315 - lr: 0.0100
# Epoch 23/300
# 100/100 [==============================] - 44s 443ms/step - loss: 0.3246 - accuracy: 0.9056 - mean_squared_error: 0.0147 - val_loss: 0.8203 - val_accuracy: 0.7412 - val_mean_squared_error: 0.0366 - lr: 0.0100
# Epoch 24/300
# 100/100 [==============================] - 45s 445ms/step - loss: 0.3082 - accuracy: 0.9112 - mean_squared_error: 0.0141 - val_loss: 0.7377 - val_accuracy: 0.7842 - val_mean_squared_error: 0.0312 - lr: 0.0100
# Epoch 25/300
# 100/100 [==============================] - 44s 443ms/step - loss: 0.2744 - accuracy: 0.9203 - mean_squared_error: 0.0129 - val_loss: 0.6751 - val_accuracy: 0.7881 - val_mean_squared_error: 0.0300 - lr: 0.0100
# Epoch 26/300
# 100/100 [==============================] - 44s 438ms/step - loss: 0.3265 - accuracy: 0.9057 - mean_squared_error: 0.0146 - val_loss: 1.1960 - val_accuracy: 0.6348 - val_mean_squared_error: 0.0515 - lr: 0.0100
# Epoch 27/300
# 100/100 [==============================] - 44s 439ms/step - loss: 0.2755 - accuracy: 0.9209 - mean_squared_error: 0.0127 - val_loss: 0.9236 - val_accuracy: 0.7207 - val_mean_squared_error: 0.0394 - lr: 0.0100
# Epoch 28/300
# 100/100 [==============================] - 44s 441ms/step - loss: 0.1924 - accuracy: 0.9456 - mean_squared_error: 0.0088 - val_loss: 0.6637 - val_accuracy: 0.7969 - val_mean_squared_error: 0.0298 - lr: 0.0100
# Epoch 29/300
# 100/100 [==============================] - 44s 436ms/step - loss: 0.4416 - accuracy: 0.8729 - mean_squared_error: 0.0192 - val_loss: 1.1782 - val_accuracy: 0.6797 - val_mean_squared_error: 0.0481 - lr: 0.0100
# Epoch 30/300
# 100/100 [==============================] - 44s 434ms/step - loss: 0.2763 - accuracy: 0.9167 - mean_squared_error: 0.0130 - val_loss: 1.0420 - val_accuracy: 0.7012 - val_mean_squared_error: 0.0453 - lr: 0.0100
# Epoch 31/300
# 100/100 [==============================] - 44s 437ms/step - loss: 0.2822 - accuracy: 0.9158 - mean_squared_error: 0.0130 - val_loss: 1.0622 - val_accuracy: 0.7139 - val_mean_squared_error: 0.0429 - lr: 0.0100
# Epoch 32/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.1475 - accuracy: 0.9603 - mean_squared_error: 0.0066 - val_loss: 0.7212 - val_accuracy: 0.7861 - val_mean_squared_error: 0.0317 - lr: 0.0100
# Epoch 33/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.1351 - accuracy: 0.9622 - mean_squared_error: 0.0060 - val_loss: 0.5426 - val_accuracy: 0.8408 - val_mean_squared_error: 0.0240 - lr: 0.0100
# Epoch 34/300
# 100/100 [==============================] - 45s 448ms/step - loss: 0.1139 - accuracy: 0.9712 - mean_squared_error: 0.0050 - val_loss: 0.6157 - val_accuracy: 0.8252 - val_mean_squared_error: 0.0256 - lr: 0.0100
# Epoch 35/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.1769 - accuracy: 0.9495 - mean_squared_error: 0.0081 - val_loss: 2.1756 - val_accuracy: 0.5508 - val_mean_squared_error: 0.0700 - lr: 0.0100
# Epoch 36/300
# 100/100 [==============================] - 44s 440ms/step - loss: 0.1362 - accuracy: 0.9625 - mean_squared_error: 0.0062 - val_loss: 0.5479 - val_accuracy: 0.8408 - val_mean_squared_error: 0.0231 - lr: 0.0100
# Epoch 37/300
# 100/100 [==============================] - 44s 442ms/step - loss: 0.1907 - accuracy: 0.9486 - mean_squared_error: 0.0083 - val_loss: 2.1360 - val_accuracy: 0.6074 - val_mean_squared_error: 0.0655 - lr: 0.0100
# Epoch 38/300
# 100/100 [==============================] - 45s 448ms/step - loss: 0.1186 - accuracy: 0.9669 - mean_squared_error: 0.0055 - val_loss: 0.5019 - val_accuracy: 0.8516 - val_mean_squared_error: 0.0220 - lr: 0.0100
# Epoch 39/300
# 100/100 [==============================] - 44s 437ms/step - loss: 0.1158 - accuracy: 0.9663 - mean_squared_error: 0.0052 - val_loss: 0.8321 - val_accuracy: 0.7773 - val_mean_squared_error: 0.0340 - lr: 0.0100
# Epoch 40/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.2148 - accuracy: 0.9357 - mean_squared_error: 0.0096 - val_loss: 0.6781 - val_accuracy: 0.8203 - val_mean_squared_error: 0.0270 - lr: 0.0100
# Epoch 41/300
# 100/100 [==============================] - 45s 447ms/step - loss: 0.0889 - accuracy: 0.9750 - mean_squared_error: 0.0040 - val_loss: 0.4949 - val_accuracy: 0.8535 - val_mean_squared_error: 0.0218 - lr: 0.0100
# Epoch 42/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0663 - accuracy: 0.9852 - mean_squared_error: 0.0027 - val_loss: 0.5311 - val_accuracy: 0.8467 - val_mean_squared_error: 0.0235 - lr: 0.0100
# Epoch 43/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.0836 - accuracy: 0.9763 - mean_squared_error: 0.0036 - val_loss: 1.1618 - val_accuracy: 0.6943 - val_mean_squared_error: 0.0454 - lr: 0.0100
# Epoch 44/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.0897 - accuracy: 0.9753 - mean_squared_error: 0.0041 - val_loss: 0.5232 - val_accuracy: 0.8506 - val_mean_squared_error: 0.0218 - lr: 0.0100
# Epoch 45/300
# 100/100 [==============================] - 44s 443ms/step - loss: 0.0582 - accuracy: 0.9869 - mean_squared_error: 0.0025 - val_loss: 0.5080 - val_accuracy: 0.8662 - val_mean_squared_error: 0.0205 - lr: 0.0100
# Epoch 46/300
# 100/100 [==============================] - 45s 449ms/step - loss: 0.0431 - accuracy: 0.9872 - mean_squared_error: 0.0019 - val_loss: 0.5360 - val_accuracy: 0.8535 - val_mean_squared_error: 0.0219 - lr: 0.0100
# Epoch 47/300
# 100/100 [==============================] - 45s 448ms/step - loss: 0.0353 - accuracy: 0.9919 - mean_squared_error: 0.0014 - val_loss: 0.4172 - val_accuracy: 0.8896 - val_mean_squared_error: 0.0168 - lr: 0.0100
# Epoch 48/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.1686 - accuracy: 0.9558 - mean_squared_error: 0.0071 - val_loss: 0.8224 - val_accuracy: 0.7881 - val_mean_squared_error: 0.0317 - lr: 0.0100
# Epoch 49/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.0654 - accuracy: 0.9816 - mean_squared_error: 0.0030 - val_loss: 0.5007 - val_accuracy: 0.8574 - val_mean_squared_error: 0.0209 - lr: 0.0100
# Epoch 50/300
# 100/100 [==============================] - 44s 439ms/step - loss: 0.0704 - accuracy: 0.9823 - mean_squared_error: 0.0030 - val_loss: 2.2683 - val_accuracy: 0.6113 - val_mean_squared_error: 0.0631 - lr: 0.0100
# Epoch 51/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.0949 - accuracy: 0.9722 - mean_squared_error: 0.0045 - val_loss: 0.6142 - val_accuracy: 0.8369 - val_mean_squared_error: 0.0253 - lr: 0.0100
# Epoch 52/300
# 100/100 [==============================] - 44s 440ms/step - loss: 0.0700 - accuracy: 0.9795 - mean_squared_error: 0.0032 - val_loss: 0.7315 - val_accuracy: 0.8008 - val_mean_squared_error: 0.0305 - lr: 0.0100
# Epoch 53/300
# 100/100 [==============================] - 44s 443ms/step - loss: 0.1123 - accuracy: 0.9707 - mean_squared_error: 0.0049 - val_loss: 0.7540 - val_accuracy: 0.8057 - val_mean_squared_error: 0.0301 - lr: 0.0100
# Epoch 54/300
# 100/100 [==============================] - 45s 447ms/step - loss: 0.0464 - accuracy: 0.9884 - mean_squared_error: 0.0020 - val_loss: 0.6170 - val_accuracy: 0.8438 - val_mean_squared_error: 0.0248 - lr: 0.0100
# Epoch 55/300
# 100/100 [==============================] - 44s 442ms/step - loss: 0.0334 - accuracy: 0.9906 - mean_squared_error: 0.0014 - val_loss: 0.4897 - val_accuracy: 0.8760 - val_mean_squared_error: 0.0194 - lr: 0.0100
# Epoch 56/300
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0276 - accuracy: 0.9934 - mean_squared_error: 0.0011 - val_loss: 0.5355 - val_accuracy: 0.8701 - val_mean_squared_error: 0.0204 - lr: 0.0100
# Epoch 57/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.0166 - accuracy: 0.9972 - mean_squared_error: 5.6710e-04 - val_loss: 0.4391 - val_accuracy: 0.8887 - val_mean_squared_error: 0.0177 - lr: 0.0100
# Epoch 58/300
# 100/100 [==============================] - 45s 450ms/step - loss: 0.0146 - accuracy: 0.9981 - mean_squared_error: 4.6626e-04 - val_loss: 0.3493 - val_accuracy: 0.9072 - val_mean_squared_error: 0.0147 - lr: 1.0000e-03
# Epoch 59/300
# 100/100 [==============================] - 46s 455ms/step - loss: 0.0118 - accuracy: 0.9981 - mean_squared_error: 3.3826e-04 - val_loss: 0.3909 - val_accuracy: 0.9121 - val_mean_squared_error: 0.0152 - lr: 1.0000e-03
# Epoch 60/300
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0142 - accuracy: 0.9975 - mean_squared_error: 4.3571e-04 - val_loss: 0.4521 - val_accuracy: 0.8828 - val_mean_squared_error: 0.0182 - lr: 1.0000e-03
# Epoch 61/300
# 100/100 [==============================] - 44s 443ms/step - loss: 0.0150 - accuracy: 0.9975 - mean_squared_error: 5.0126e-04 - val_loss: 0.3705 - val_accuracy: 0.9033 - val_mean_squared_error: 0.0151 - lr: 1.0000e-03
# Epoch 62/300
# 100/100 [==============================] - 44s 442ms/step - loss: 0.0081 - accuracy: 0.9994 - mean_squared_error: 1.4988e-04 - val_loss: 0.3930 - val_accuracy: 0.9102 - val_mean_squared_error: 0.0150 - lr: 1.0000e-03
# Epoch 63/300
# 100/100 [==============================] - 44s 441ms/step - loss: 0.0101 - accuracy: 0.9984 - mean_squared_error: 3.1049e-04 - val_loss: 0.3981 - val_accuracy: 0.9033 - val_mean_squared_error: 0.0152 - lr: 1.0000e-03
# Epoch 64/300
# 100/100 [==============================] - 45s 443ms/step - loss: 0.0093 - accuracy: 0.9987 - mean_squared_error: 2.2177e-04 - val_loss: 0.3888 - val_accuracy: 0.9004 - val_mean_squared_error: 0.0155 - lr: 1.0000e-03
# Epoch 65/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0100 - accuracy: 0.9984 - mean_squared_error: 3.0492e-04 - val_loss: 0.3685 - val_accuracy: 0.9160 - val_mean_squared_error: 0.0143 - lr: 1.0000e-03
# Epoch 66/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0086 - accuracy: 0.9991 - mean_squared_error: 2.0796e-04 - val_loss: 0.3742 - val_accuracy: 0.9150 - val_mean_squared_error: 0.0143 - lr: 1.0000e-03
# Epoch 67/300
# 100/100 [==============================] - 44s 442ms/step - loss: 0.0088 - accuracy: 0.9997 - mean_squared_error: 1.8776e-04 - val_loss: 0.3891 - val_accuracy: 0.8975 - val_mean_squared_error: 0.0158 - lr: 1.0000e-03
# Epoch 68/300
# 100/100 [==============================] - 44s 443ms/step - loss: 0.0096 - accuracy: 0.9984 - mean_squared_error: 2.6597e-04 - val_loss: 0.3762 - val_accuracy: 0.9043 - val_mean_squared_error: 0.0147 - lr: 1.0000e-03
# Epoch 69/300
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0067 - accuracy: 1.0000 - mean_squared_error: 1.0534e-04 - val_loss: 0.3818 - val_accuracy: 0.9004 - val_mean_squared_error: 0.0154 - lr: 1.0000e-04
# Epoch 70/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0064 - accuracy: 0.9997 - mean_squared_error: 1.0055e-04 - val_loss: 0.4237 - val_accuracy: 0.8916 - val_mean_squared_error: 0.0167 - lr: 1.0000e-04
# Epoch 71/300
# 100/100 [==============================] - 44s 441ms/step - loss: 0.0078 - accuracy: 0.9997 - mean_squared_error: 1.3465e-04 - val_loss: 0.3716 - val_accuracy: 0.9092 - val_mean_squared_error: 0.0145 - lr: 1.0000e-04
# Epoch 72/300
# 100/100 [==============================] - 44s 439ms/step - loss: 0.0097 - accuracy: 0.9991 - mean_squared_error: 2.5238e-04 - val_loss: 0.3837 - val_accuracy: 0.9004 - val_mean_squared_error: 0.0156 - lr: 1.0000e-04
# Epoch 73/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.0086 - accuracy: 0.9991 - mean_squared_error: 2.1592e-04 - val_loss: 0.3540 - val_accuracy: 0.9111 - val_mean_squared_error: 0.0138 - lr: 1.0000e-04
# Epoch 74/300
# 100/100 [==============================] - 45s 447ms/step - loss: 0.0091 - accuracy: 0.9991 - mean_squared_error: 2.3063e-04 - val_loss: 0.3693 - val_accuracy: 0.9072 - val_mean_squared_error: 0.0143 - lr: 1.0000e-04
# Epoch 75/300
# 100/100 [==============================] - 44s 442ms/step - loss: 0.0077 - accuracy: 0.9994 - mean_squared_error: 1.4778e-04 - val_loss: 0.3912 - val_accuracy: 0.8975 - val_mean_squared_error: 0.0158 - lr: 1.0000e-04
# Epoch 76/300
# 100/100 [==============================] - 45s 445ms/step - loss: 0.0067 - accuracy: 1.0000 - mean_squared_error: 1.2525e-04 - val_loss: 0.3896 - val_accuracy: 0.9053 - val_mean_squared_error: 0.0149 - lr: 1.0000e-04
# Epoch 77/300
# 100/100 [==============================] - 44s 443ms/step - loss: 0.0085 - accuracy: 0.9994 - mean_squared_error: 2.1013e-04 - val_loss: 0.4157 - val_accuracy: 0.9023 - val_mean_squared_error: 0.0162 - lr: 1.0000e-04
# Epoch 78/300
# 100/100 [==============================] - 45s 446ms/step - loss: 0.0092 - accuracy: 0.9984 - mean_squared_error: 2.6555e-04 - val_loss: 0.3922 - val_accuracy: 0.9043 - val_mean_squared_error: 0.0155 - lr: 1.0000e-04
# Epoch 79/300
# 100/100 [==============================] - 45s 444ms/step - loss: 0.0071 - accuracy: 1.0000 - mean_squared_error: 1.3575e-04 - val_loss: 0.4164 - val_accuracy: 0.9004 - val_mean_squared_error: 0.0161 - lr: 1.0000e-05
# Epoch 80/300
# 100/100 [==============================] - 45s 450ms/step - loss: 0.0090 - accuracy: 0.9997 - mean_squared_error: 2.1614e-04 - val_loss: 0.4391 - val_accuracy: 0.8857 - val_mean_squared_error: 0.0173 - lr: 1.0000e-05

# %%
#OUTPUT TEST PREDICTIONS
#load testing data
model.load_weights(checkpoint_filepath)
#print(classification_report(test['Score'], y_pred))

#from glob import glob
#te_image_count = len(list(glob('./dataset/test/*.jpg')))
#print(te_image_count)

#from https://github.com/zhixuhao/unet/blob/master/data.py
def testGenerator(test_path,num_image = 30,target_size = (224,224),flag_multi_class = False,):
    for i in range(num_image):
        img = io.imread(os.path.join(test_path,f"{i+200001}.jpg"))
        # img = img / 255
        img = tf.keras.applications.resnet_v2.preprocess_input(
          img, data_format=None
        )
        img = trans.resize(img,target_size)
        # img = np.reshape(img,img.shape+(1,)) if (not flag_multi_class) else img
        img = np.reshape(img,(1,)+img.shape)
        yield img

#predict
testGene = testGenerator("/content/drive/My Drive/cs231n/assignments/assignment6/test_images", num_image = 3469) #couldn't get glob to work with google drive pathing
results = model.predict(testGene)

img_ids = []
labels = []
indices = np.argmax(results, axis=1)
idx = 0
for dec in indices:
  img_ids.append('{}.jpg'.format(idx+200001))
  idx = idx+1
  if dec == 0:
    labels.append('bacterial_leaf_blight')
  elif dec == 1:
    labels.append('bacterial_leaf_streak')
  elif dec == 2:
    labels.append('bacterial_panicle_blight')
  elif dec == 3:
    labels.append('blast')
  elif dec == 4:
    labels.append('brown_spot')
  elif dec == 5:
    labels.append('dead_heart')
  elif dec == 6:
    labels.append('downy_mildew')
  elif dec == 7:
    labels.append('hispa')
  elif dec == 8:
    labels.append('normal')
  elif dec == 9:
    labels.append('tungro')

d = {"image_id": img_ids,
     "label": labels}
df = pd.DataFrame(data=d)
df.to_csv("/content/drive/My Drive/cs231n/assignments/assignment6/Paddy_Doctor_Predictions.csv")
